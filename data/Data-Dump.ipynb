# %%
# !pip install Faker
from faker import Faker
# Out:
# Requirement already satisfied: Faker in c:\users\annpinto\anaconda3\lib\site-packages (11.3.0)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\annpinto\anaconda3\lib\site-packages (from Faker) (2.8.2)
# Requirement already satisfied: text-unidecode==1.3 in c:\users\annpinto\anaconda3\lib\site-packages (from Faker) (1.3)
# Requirement already satisfied: six>=1.5 in c:\users\annpinto\anaconda3\lib\site-packages (from python-dateutil>=2.4->Faker) (1.16.0)

# %%
import pandas as pd
import random
from faker import Faker
from random import randrange
from datetime import datetime

# %%
nr_of_customers = 10000

fake = Faker('de_DE')

customers = []

for customers_id in range(nr_of_customers):

    #Type of device
    d_type = random.choice(["Laptop", "Smart Phone", "Feature Phone"])
    
    #Device ID
    device_ID = fake.ean(length=8)
    
    #Device Brand
    if d_type == "Laptop":
        d_brand = random.choice(["Apple", "HP", "Dell", "Lenovo"])
    elif d_type == "Smart Phone":
        d_brand = random.choice(["Apple", "Blackberry", "OnePlus", "Oppo", "Nokia", "Samsung"])
    else:
        #feature phone
        d_brand = random.choice(["Nokia", "Samsung"])
    
    #Device model
    if d_brand == "Apple" and d_type == "Laptop":
        d_model = random.choice(["MacBook", "ProBook"])
    elif d_brand == "Lenovo":    
        d_model = random.choice(["Ideapad", "ThinkPad"])
    elif d_brand == "Dell":
        d_model = random.choice(["Inspiron", "Vostro"])
    elif d_brand == "HP":
        d_model = random.choice(["EliteBook", "Probook", "Pavilion"])
    elif d_brand == "Apple" and d_type == "Smart Phone":
        d_model = random.choice(["Iphone 5", "Iphone 5S", "Iphone SE", "Iphone 6", "Iphone 6S", "Iphone 7", "Iphone 8", "Iphone X", "Iphone XR", "Iphone XS", "Iphone 11", "Iphone 11", "Iphone 12", "Iphone 13"])
    elif d_brand == "Blackberry":
        d_model = random.choice(["Q5", "Q10", "Curve", "Torch", "Leap", "Passport", "Keyone", "Aurora"])
    elif d_brand == "OnePlus":
        d_model = random.choice(["OnePlus 6", "OnePlus 6T", "OnePlus 7", "OnePlus 7pro", "OnePlus 7T", "OnePlus nord", "OnePlus 8", "OnePlus 9R"])
    elif d_brand == "Oppo":
        d_model = random.choice(["A3s", "A52", "A11k", "Find 7", "N1", "Neo", "Joy", "R1"])
    elif d_brand == "Nokia" and d_type == "Smart Phone":
        d_model = random.choice(["X100", "G300", "T20", "G50", "XR20", "X10", "C20 Plus", "X20"])
    elif d_brand == "Samsung" and d_type == "Smart Phone":
        d_model = random.choice(["Galaxy A6", "Galaxy J7 duo", "Galaxy S9", "Galaxy Note 9", "Galaxy A8s"])
    elif d_brand == "Nokia" and d_type == "Feature Phone":
        d_model = random.choice(["5310", "125", "225", "215", "6300", "8000"])
    else:
        #samsung feature phone
        d_model = random.choice(["5310", "125", "225", "215", "6300", "8000"])
    
    
    #Manufacture date
    Md1 = datetime.strptime(f'1/1/2014', '%m/%d/%Y')
    Md2 = datetime.strptime(f'12/31/2020', '%m/%d/%Y')
    manufacture_date = fake.date_between(Md1, Md2)
    
    #Date of Allocation
    d1 = datetime.strptime(f'1/1/2021', '%m/%d/%Y')
    d2 = datetime.strptime(f'8/10/2021', '%m/%d/%Y')
    allocation_date = fake.date_between(d1, d2)
    
    #Water Damage
    water_damage = random.choice(["Yes", "No"])
    
    #Keypad, keyboard, touch responsive
    d_responsive = random.choice(["Yes", "No"])
    
    #Device in use
    if d_responsive == "No":
        device_in_use = "No"
    else:
        device_in_use = random.choice(["Yes", "No"])
    
    
    
    #Battery Health
    battery_health = random.choice(["Good", "Average", "Poor"])
    
    #usage(hrs)
    if battery_health == "Good":
        usage = fake.pyfloat(right_digits=2, positive=True, min_value=1, max_value=20)
    elif battery_health == "Average":
        usage = fake.pyfloat(right_digits=2, positive=True, min_value=1, max_value=10)
    else:
        usage = fake.pyfloat(right_digits=2, positive=True, min_value=1, max_value=5)
    
    #Latency(ms)
    latency = random.choice(["Good", "Average", "Poor"])
    
    customers.append([d_type, device_ID, d_brand, d_model, manufacture_date, allocation_date, device_in_use, water_damage, d_responsive, battery_health, usage, latency])

customers_df = pd.DataFrame(customers, columns=['Device_type','Device_ID', 'Device_brand', 'Device_model','Manufacture_Date', 'Allocation_Date','device_in_use', 'water_damage', 'device_responsive', 'battery_health', 'Usage(hrs)', 'Latency(ms)']) 
   
customers_df.to_csv('V2_Dummy-Data.csv')
pd.pandas.set_option('display.max_columns', None)
print(customers_df.head(10))
# Out:
#      Device_type Device_ID Device_brand  Device_model Manufacture_Date  \
# 0  Feature Phone  28679608      Samsung           125       2015-11-20
# 1  Feature Phone  05679508      Samsung          8000       2017-12-04
# 2    Smart Phone  05170654      OnePlus  OnePlus nord       2018-04-03
# 3    Smart Phone  23608139         Oppo          A11k       2017-09-29
# 4    Smart Phone  27235188      OnePlus    OnePlus 7T       2017-03-05
# 5         Laptop  33554549         Dell        Vostro       2018-09-04
# 6         Laptop  23828711       Lenovo       Ideapad       2014-10-26
# 7  Feature Phone  00781534      Samsung           215       2016-06-11
# 8    Smart Phone  98483792   Blackberry         Curve       2020-04-16
# 9         Laptop  40113869           HP     EliteBook       2017-10-14
#
#   Allocation_Date device_in_use water_damage device_responsive battery_health  \
# 0      2021-03-02            No           No                No           Good
# 1      2021-01-25            No           No                No        Average
# 2      2021-03-17            No           No                No           Good
# 3      2021-02-27            No          Yes                No           Good
# 4      2021-06-28           Yes          Yes               Yes           Good
# 5      2021-02-28            No          Yes                No        Average
# 6      2021-03-23            No           No                No        Average
# 7      2021-03-16            No          Yes               Yes        Average
# 8      2021-07-09           Yes          Yes               Yes        Average
# 9      2021-05-15            No          Yes                No        Average
#
#    Usage(hrs) Latency(ms)
# 0        3.41        Good
# 1        9.73     Average
# 2       10.82        Poor
# 3        6.25        Poor
# 4       14.25        Poor
# 5        2.54        Poor
# 6        5.95        Good
# 7        4.45     Average
# 8        1.18        Poor
# 9        7.35        Good

# %%
#end
